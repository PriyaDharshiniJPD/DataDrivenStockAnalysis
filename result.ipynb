# %%
# VOLATILITY
import pandas as pd
import matplotlib.pyplot as plt
import os

folder_path=r"E:\python project\project2\output_csv"

all_data=[]

for file in os.listdir(folder_path):
    if file.endswith(".csv"):
        full_path=os.path.join(folder_path,file)
        df=pd.read_csv(full_path)
        all_data.append(df)
        
df=pd.concat(all_data,ignore_index=True)

df['date']=pd.to_datetime(df['date'])

df=df.sort_values(['Ticker','date'])

df['prev_close']=df.groupby('Ticker')['close'].shift(1)
df['daily_return']=(df['close']-df['prev_close'])/df['prev_close']

volatility=df.groupby('Ticker')['daily_return'].std()

top10 = volatility.nlargest(10)


output_file=r"E:\python project\project2\top10_volatile_stocks.csv"
top10.to_csv(output_file,header=['Volatility'])

print("CSV created successfully:", output_file)
# Out:
# CSV created successfully: E:\python project\project2\top10_volatile_stocks.csv

# %%
# CUMULATIVE
import pandas as pd
import os

folder_path=r"E:\python project\project2\output_csv"

all_data=[]

for file in os.listdir(folder_path):
    if file.endswith(".csv"):
        full_path=os.path.join(folder_path,file)
        df=pd.read_csv(full_path)
        all_data.append(df)
        
df=pd.concat(all_data,ignore_index=True)

df['date']=pd.to_datetime(df['date'])

df=df.sort_values(['Ticker','date'])

df['prev_close']=df.groupby('Ticker')['close'].shift(1)
df['daily_return']=(df['close']-df['prev_close'])/df['prev_close']

df['cum_return']=df.groupby('Ticker')['daily_return'].transform(lambda x: (1+x).cumprod()-1)

last=df.groupby('Ticker').tail(1)
top5_tickers= last.sort_values('cum_return',ascending=False)[['Ticker','cum_return']].head(5)

output_file = r"E:\python project\project2\top5_cumulative_return.csv"
top5_tickers.to_csv(output_file, index=False)

print("CSV File Created:", output_file)
# Out:
# CSV File Created: E:\python project\project2\top5_cumulative_return.csv

# %%
#TOP5 GAINER AND TOP 5 LOSER
import pandas as pd
import os

folder_path=r"E:\python project\project2\output_csv"

all_data=[]

for file in os.listdir(folder_path):
    if file.endswith(".csv"):
        full_path=os.path.join(folder_path,file)
        df=pd.read_csv(full_path)
        all_data.append(df)
        
df=pd.concat(all_data,ignore_index=True)

df['date']=pd.to_datetime(df['date'])

df=df.sort_values(['Ticker','date'])

df['month'] = df['date'].dt.to_period('M')

monthly = df.groupby(['Ticker', 'month'])['close'].agg(['first', 'last'])
monthly['return'] = (monthly['last'] - monthly['first']) / monthly['first']
monthly = monthly.reset_index()

months = sorted(monthly['month'].unique())

combined_list=[]

for m in months:
    data = monthly[monthly['month'] == m]

   
    top5 = data.nlargest(5, 'return').copy()
    top5['Type']='Top gainer'
    
    bottom5 = data.nsmallest(5, 'return').copy()
    bottom5['Type']='Top losser'
    
    top5['Month']=m
    bottom5['Month']=m
    
    combined_list.append(top5)
    combined_list.append(bottom5)
    
    final_df=pd.concat(combined_list,ignore_index=True)
    
    final_df = final_df[['Ticker', 'return', 'Type', 'month']]
    final_df.rename(columns={'return':'Return'}, inplace=True) 
    
    output_file=r"E:\python project\project2\Top5_Gainers_Losers_AllMonths.csv"
    final_df.to_csv(output_file,index=False)
    
    print("final merged csv",output_file)
# Out:
# final merged csv E:\python project\project2\Top5_Gainers_Losers_AllMonths.csv
# final merged csv E:\python project\project2\Top5_Gainers_Losers_AllMonths.csv
# final merged csv E:\python project\project2\Top5_Gainers_Losers_AllMonths.csv
# final merged csv E:\python project\project2\Top5_Gainers_Losers_AllMonths.csv
# final merged csv E:\python project\project2\Top5_Gainers_Losers_AllMonths.csv
# final merged csv E:\python project\project2\Top5_Gainers_Losers_AllMonths.csv
# final merged csv E:\python project\project2\Top5_Gainers_Losers_AllMonths.csv
# final merged csv E:\python project\project2\Top5_Gainers_Losers_AllMonths.csv
# final merged csv E:\python project\project2\Top5_Gainers_Losers_AllMonths.csv
# final merged csv E:\python project\project2\Top5_Gainers_Losers_AllMonths.csv
# final merged csv E:\python project\project2\Top5_Gainers_Losers_AllMonths.csv
# final merged csv E:\python project\project2\Top5_Gainers_Losers_AllMonths.csv
# ...

# %%
#STOCK CORERELATION
import pandas as pd
import os

folder_path=r"E:\python project\project2\output_csv"

all_data=[]

for file in os.listdir(folder_path):
    if file.endswith(".csv"):
        full_path=os.path.join(folder_path,file)
        df=pd.read_csv(full_path)
        all_data.append(df)
        
df=pd.concat(all_data,ignore_index=True)

df['date']=pd.to_datetime(df['date'])

pivot_df = df.pivot_table(index='date', columns='Ticker', values='close')

corr_matrix = pivot_df.corr()

corr_matrix.index.name = "Stock1"
corr_matrix.columns.name = "Stock2"

corr_flat = corr_matrix.stack().reset_index()
corr_flat.columns = ['Stock1', 'Stock2', 'Correlation']

output_corr_csv = r"E:\python project\project2\Stock_Correlation_Matrix.csv"
corr_flat.to_csv(output_corr_csv, index=False)


print("Correlation matrix saved at",output_csv)
# Out:
# Correlation matrix saved at E:\python project\project2\Stock_Correlation_Matrix.csv

# %%
#SECTOR FILE
import pandas as pd

data = {
    "Ticker": [
        "ADANIENT","ADANIPORTS","APOLLOHOSP","ASIANPAINT","AXISBANK","BAJAJ-AUTO","BAJAJFINSV","BAJFINANCE",
        "BEL","BHARTIARTL","BPCL","BRITANNIA","CIPLA","COALINDIA","DRREDDY","EICHERMOT","GRASIM","HCLTECH",
        "HDFCBANK","HDFCLIFE","HEROMOTOCO","HINDALCO","HINDUNILVR","ICICIBANK","INDUSINDBK","INFY","ITC",
        "JSWSTEEL","KOTAKBANK","LT","M&M","MARUTI","NESTLEIND","NTPC","ONGC","POWERGRID","RELIANCE",
        "SBILIFE","SBIN","SHRIRAMFIN","SUNPHARMA","TATACONSUM","TATAMOTORS","TATASTEEL","TCS","TECHM",
        "TITAN","TRENT","ULTRACEMCO","WIPRO"
    ],
    "Sector": [
        "Industrials","Transportation","Healthcare","Consumer Goods","Financial Services","Automobile",
        "Financial Services","Financial Services","Defence","Telecom","Energy","Consumer Goods",
        "Pharmaceuticals","Mining","Pharmaceuticals","Automobile","Materials","IT","Financial Services",
        "Insurance","Automobile","Metals","Consumer Goods","Financial Services","Financial Services","IT",
        "Consumer Goods","Metals","Financial Services","Infrastructure","Automobile","Automobile",
        "Consumer Goods","Energy","Energy","Energy","Conglomerate","Insurance","Financial Services",
        "Financial Services","Pharmaceuticals","Consumer Goods","Automobile","Metals","IT","IT",
        "Consumer Goods","Retail","Cement","IT"
    ]
}

df = pd.DataFrame(data)
df.to_csv("sector_mapping.csv", index=False)

print("sector_mapping.csv created")
# Out:
# sector_mapping.csv created

# %%
#SECTOR PERFORMANCE
import pandas as pd
import os

folder_path=r"E:\python project\project2\output_csv"

all_data=[]

for file in os.listdir(folder_path):
    if file.endswith(".csv"):
        full_path=os.path.join(folder_path,file)
        df=pd.read_csv(full_path)
        all_data.append(df)
        
df=pd.concat(all_data,ignore_index=True)

df['date']=pd.to_datetime(df['date'])

df=df.sort_values(['Ticker','date'])

first_close = df.groupby("Ticker")["close"].first()
last_close = df.groupby("Ticker")["close"].last()

yearly_return = ((last_close - first_close) / first_close).reset_index()
yearly_return.columns = ["Ticker", "Yearly_Return"]

sector_df = pd.read_csv(r"E:\python project\project2\sector_mapping.csv")

merged = pd.merge(yearly_return, sector_df, on="Ticker", how="left")

sector_performance = merged.groupby("Sector")["Yearly_Return"].mean().sort_values(ascending=False)

output_file = r"E:\python project\project2\Sector_Performance.csv"
sector_performance.to_csv(output_file, header=["Average_Yearly_Return"])

print("Sector performance CSV created",output_file)
# Out:
# Sector performance CSV created E:\python project\project2\Sector_Performance.csv

# %%
import pandas as pd
import os

folder_path=r"E:\python project\project2\output_csv"

all_data=[]

for file in os.listdir(folder_path):
    if file.endswith(".csv"):
        full_path=os.path.join(folder_path,file)
        df=pd.read_csv(full_path)
        all_data.append(df)
        
df=pd.concat(all_data,ignore_index=True)

df['date']=pd.to_datetime(df['date'])

df=df.sort_values(['Ticker','date'])
  

df['prev_close']=df.groupby('Ticker')['close'].shift(1)
df['daily_return']=(df['close']-df['prev_close'])/df['prev_close']

df['cum_return']=df.groupby('Ticker')['daily_return'].transform(lambda x: (1+x).cumprod()-1)

last=df.groupby('Ticker').tail(1)
top5_tickers= last.sort_values('cum_return',ascending=False)['Ticker'].head(5).tolist()

# %%
import pandas as pd
import os

folder_path = r"E:\python project\project2\output_csv"

all_data = []


for file in os.listdir(folder_path):        #---- LOAD ALL CSV FILES 
    if file.endswith(".csv"):
        full_path = os.path.join(folder_path, file)
        df = pd.read_csv(full_path)
        all_data.append(df)

# Combine everything into one dataframe
df = pd.concat(all_data, ignore_index=True)


df['date'] = pd.to_datetime(df['date'])                   # ---- CLEAN DATA 
df['close'] = pd.to_numeric(df['close'], errors='coerce')

-
df = df.sort_values(['Ticker', 'date'])                # ---- SORT DATA 


first_close = df.groupby('Ticker')['close'].first()    # ---- CALCULATE YEARLY RETURN 
last_close = df.groupby('Ticker')['close'].last()

yearly_return = (last_close - first_close) / first_close
yearly_return = yearly_return.reset_index()
yearly_return.columns = ['Ticker', 'yearly_return']


top10_green = yearly_return.sort_values(by='yearly_return', ascending=False).head(10)   # --- TOP 10 GREEN STOCKS 
green_output = r"E:\python project\project2\top10_green_stocks.csv"
top10_green.to_csv(green_output, index=False)


top10_loss = yearly_return.sort_values(by='yearly_return', ascending=True).head(10)    # --- TOP 10 LOSS STOCKS 
loss_output = r"E:\python project\project2\top10_loss_stocks.csv"
top10_loss.to_csv(loss_output, index=False)


green_count = (yearly_return['yearly_return'] > 0).sum()             #--- MARKET SUMMARY 
red_count = (yearly_return['yearly_return'] < 0).sum()
avg_close = df['close'].mean()

summary_df = pd.DataFrame({
    "Metric": ["Green Stocks", "Red Stocks", "Average Close Price"],
    "Value": [green_count, red_count, avg_close]
})

summary_output = r"E:\python project\project2\market_summary.csv"
summary_df.to_csv(summary_output, index=False)


print("CSV files created successfully:")      #---- PRINT SUCCESS 
print(" -", green_output)
print(" -", loss_output)
print(" -", summary_output)
# Out:
# CSV files created successfully:
#  - E:\python project\project2\top10_green_stocks.csv
#  - E:\python project\project2\top10_loss_stocks.csv
#  - E:\python project\project2\market_summary.csv
